# %% [markdown]
# # 1. 가상환경 설정

# %%
# 터미널
# python3 -m venv .venv - 독립적인 라이브러리 생성
# source .venv/bin/activate - 가상환경 활성화
# pip install requests pandas - 필요한 라이브러리 설치
# pip freeze > requirements.txt - 설치된 라이브러리 목록 저장
# pip install beautifulsoup4 - 웹 크롤링 라이브러리 설치
# playwright install chromium - playwright로 크롬 브라우저 설치
# pip install playwright - playwright 설치
